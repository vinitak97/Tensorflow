# %%
import numpy as np
x_data=np.linspace(0,10,10)+np.random.uniform(-1.5,1.5,10)
x_data
# Out:
# array([ 0.45192595,  2.03616301,  2.42030792,  4.46525226,  5.23260437,
#         5.18236478,  6.51144379,  8.05880242,  7.88396676, 11.39425898])

# %%
y_label=np.linspace(0,10,10)+np.random.uniform(-1.5,1.5,10)
y_label
# Out:
# array([-1.15293124, -0.37786806,  2.92590662,  2.23462382,  5.65346013,
#         4.51595437,  7.73766603,  7.98439073,  7.40941542,  8.90796566])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x_data, y_label, '*')

# %%
np.random.rand(2)
# Out:
# array([0.48832949, 0.51390087])

# %%
import tensorflow as tf
m=tf.Variable(0.94)
b=tf.Variable(0.47)

# %%
error=0
for x,y in zip(x_data, y_label):
  y_hat=m*x+b
  error+=(y-y_hat)**2

# %%
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.001)

# %%
train=optimizer.minimize(error)

# %%
init=tf.global_variables_initializer()

# %%
with tf.Session() as sess:
  sess.run(init)
  training_steps=1000
  for i in range(training_steps):
    sess.run(train)
  final_slope,final_intercept=sess.run([m,b])

# %%
x_test=np.linspace(-1,11,10)
y_pred_plot=final_slope*x_test+final_intercept

# %%
plt.plot(x_test, y_pred_plot, 'r')
plt.plot(x_data, y_label, '*')

# %%
#Tensorflow regression example

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf

# %%
x_adat=np.linspace(0.0, 10, 10000000)

# %%
noise=np.random.randn(len(x_data))

# %%
y_true=(0.5*x_data)+5+noise

# %%
x_df=pd.DataFrame(data=x_data, columns=['x data'])

# %%
y_df=pd.DataFrame(data=y_true, columns=['y'])

# %%
my_data=pd.concat([x_df, y_df], axis=1)

# %%
my_data.head()
# Out:
#      x data         y
# 0  0.451926  5.425178
# 1  2.036163  5.971544
# 2  2.420308  6.026271
# 3  4.465252  6.537627
# 4  5.232604  8.697849

# %%
my_data.sample(n=250).plot(kind='scatter', x='x data', y='y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-1e0e28ec404a> in <module>()
# ----> 1 my_data.sample(n=25).plot(kind='scatter', x='x data', y='y')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    3439                              "provide positive value.")
#    3440
# -> 3441         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    3442         return self.take(locs, axis=axis, is_copy=False)
#    3443
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
batch_size=8

# %%
np.random.randn(2)
# Out:
# array([-0.6533295 ,  0.04945754])

# %%
m=tf.Variable(0.10)
b=tf.Variable(0.98)

# %%
xph=tf.placeholder(tf.float32, [batch_size])
yph=tf.placeholder(tf.float32, [batch_size])

# %%
y_model=m*xph+b

# %%
error=tf.reduce_sum(tf.square(yph-y_model))

# %%
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.0001)
train=optimizer.minimize(error)

# %%
init=tf.global_variables_initializer()

# %%
with tf.Session() as sess:
  sess.run(init)
  batches=1000
  for i in range(batches):
    rand_ind=np.random.randint(len(x_data), size=batch_size)
    feed={xph:x_data[rand_ind], yph:y_true[rand_ind]}
    sess.run(train,feed_dict=feed)
  model_m, model_b=sess.run([m,b])

# %%
model_m
# Out:
# 0.8766343

# %%
model_b
# Out:
# 2.3339584

# %%
y_hat=x_data*model_m+model_b

# %%
my_data.sample(n=250).plot(kind='scatter', x='x data', y='y')
plt.plot(x_data, y_hat, 'r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-505c26b029d1> in <module>()
# ----> 1 my_data.sample(n=250).plot(kind='scatter', x='x data', y='y')
#       2 plt.plot(x_data, y_hat, 'r')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    3439                              "provide positive value.")
#    3440
# -> 3441         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    3442         return self.take(locs, axis=axis, is_copy=False)
#    3443
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
